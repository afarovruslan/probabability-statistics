# %%
from scipy.stats import cauchy, uniform, norm, f, kstwobign, poisson
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF
import seaborn as sns

# %% [markdown]
# ![image.png](attachment:3cc8c80a-4329-48cd-965a-3f1cf9f36c62.png)

# %%
sel_size = 1000
count_sel = 101
num_experiments = 3

# %%
def get_statistics(theta: float, distribution, statistic1, statistic2):
  statistics1 = np.zeros(count_sel)
  statistics2 = np.zeros(count_sel)
  for i in range(count_sel):
    selection = distribution(theta)
    statistics1[i] = statistic1(selection)
    statistics2[i] = statistic2(selection)
  return statistics1, statistics2

def plot_statistics(theta: float, statistics1, statistics2, title1, title2):
  plt.figure(figsize=(15, 5))
  plt.subplot(131)
  plt.hist(statistics1, bins=30, color='c', edgecolor='k', alpha=0.65)
  plt.title(title1)
  plt.axvline(theta, color='k', linestyle='dashed', linewidth=1)
  plt.subplot(132)
  plt.hist(statistics2, bins=30, color='c', edgecolor='k', alpha=0.65)
  plt.title(title2)
  plt.axvline(theta, color='k', linestyle='dashed', linewidth=1)
  plt.show()

def plot_one_asymptotic_normally(apply, statistics, var: float, title: str):
    arr = apply(statistics)
    count, bins, ignored = plt.hist(arr, bins=10, density=True)
    mu = 0
    if var != 0:
        plt.plot(bins, 1/(np.sqrt(2 * np.pi * var)) *
                 np.exp( - (bins - mu)**2 / (2 * var)),
                 linewidth=2, color='r')
    plt.title(title)

def plot_asymptotic_normally(theta: float, statistics1, statistics2, var1: float = 0, var2: float = 0, title1: str = 'median', title2: str = 'mean'):
  to_value = lambda x: np.sqrt(count_sel) * (x - theta)
  aplyall = np.vectorize(to_value)
  plt.figure(figsize=(15, 5))
  plt.subplot(131)
  plot_one_asymptotic_normally(aplyall, statistics1, var1, title1)
  plt.subplot(132)
  print(var2)
  plot_one_asymptotic_normally(aplyall, statistics2, var2, title2)
  plt.show()

def check_statistics(distribution, statistic1=np.median, statistic2=np.mean, title1='median', title2='mean'):
  statistics = []
  for i in range(num_experiments):
    theta = uniform.rvs(loc=0, scale=10)
    statistics1, statistics2 = get_statistics(theta, distribution, statistic1, statistic2)
    statistics.append((theta, statistics1, statistics2))
    plot_statistics(theta, statistics1, statistics2, title1, title2)
  return statistics

# %%
cuachy_statistics = check_statistics(lambda theta : cauchy.rvs(loc=theta, size=sel_size))

# %% [markdown]
# ![image.png](attachment:51b3812a-d15b-4b79-9314-a6981248f38e.png)

# %% [markdown]
# Видно, что в случае среднего, статистика может принимать большие значения и сильно отличатся от настоящего параметра, чего нет у медианаы
# Дело в том, что $\overline{X} - $ сильно состоятельная оценка матожидания, а матожидание у распределения Коши не существует
# По теореме о выборочной медиане, выборочная медиана является асимптотически нормальной оценкой $z_{1/2} = \theta$ с асимптотической дисперсией $\frac{\pi}{4}$, а следовательно и состоятельной оценкой $\theta$.
#
# Докажем, что $\overline{X}$ - не сотстоятельная оценка $\theta$. Рассмотрим, $\psi_{X_1}(t) = e^{\theta it - |t|}$. Тогда $\psi_{\overline{X}}(t) = \psi_{X_1}^n(\frac{t}{n}) = \psi_{X_1}(t) \rightarrow \overline{X}$ имеет такое же распределение как и $X_1$. Тогда $\psi_{\overline{X}}(t) \to \psi_{X_1}(t) \ne$ распределение константы, то есть среднее не является состоятельной оценкой, а следовательно не является и асимптотически нормальной

# %%
for theta, medians, means in cuachy_statistics:
  plot_asymptotic_normally(theta, medians, means, np.pi/4)
# Out:
# 0
# 0
# 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
normal_statistics = check_statistics(lambda theta : norm.rvs(loc=theta, size=sel_size))

# %% [markdown]
# На диаграммах видно, что разброс относительно верного значения у выборочной медианы больше. По УЗБЧ $\overline{X}$ - сильно состоятельная оценка $\theta$, а по ЦПТ $\overline{X}$ - асимптотически нормальная оценка с асимптотической дисперисией 1. Выборочная медиана же асимптотически нормальная(по всё той же теореме) с асимптотической дисперсией $\frac{\pi}{2} →$ выборочное среднее лучше в асимптотическом подходе чем выборочная медиана, что отражено на графике.

# %%
for theta, medians, means in normal_statistics:
  plot_asymptotic_normally(theta, medians, means, np.pi/2, 1)
# Out:
# 1
# 1
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Найдем указанные в условии статистики:
# $L(\theta) = \frac{1}{\theta^n} I_{0 \le X_{(1)} \le X_{(n)} \le \theta} \rightarrow X_{(n)} - $ достаточная статистика по критерию факторизации.
# $\mathbb{E} \varphi(X_{(n)} = \frac{n}{\theta^n}\int_{0}^{\theta} \varphi(x) x^{n - 1} dx \rightarrow \int_{0}^{\theta} \varphi(x) x^{n - 1} dx = 0 \forall \theta$, продиффиринциируем по $\theta$ и получим, что $\varphi(x)$ = 0 $\rightarrow X_{(n)} - $ полная статистика. Решая уравнения несмещенности, получаем, что
# $\hat{theta_1} = \frac{n + 1}{n} X_{(n)}$. Оценка по методу моментов $\hat{\theta_2} = 2\overline{X}$

# %%
theta_1 = lambda selection : (sel_size + 1) / sel_size * np.max(selection)
theta_2 = lambda selection : 2 * np.mean(selection)

# %%
uniform_statistics = check_statistics(lambda theta : uniform.rvs(scale=theta, size=sel_size), theta_1, theta_2, 'optimal', 'moment')

# %%
for theta, statistics1, statistics2 in cuachy_statistics:
  plot_asymptotic_normally(theta, statistics2, statistics1, var2=theta * theta / 6, title1='moment', title2='optimal')
# Out:
# 9.124520965905488
# 5.000627942888546
# 13.05620389188334

# %% [markdown]
# Оценка $\hat{\theta_1}$ является сильно состоятельной (см. задачу 7 первой домашки). Найдем $F_{\sqrt{n}(X_{(n)} - \theta)}$:
# $$F_{\sqrt{n}(X_{(n)} - \theta}(x) = F_{X_{(n)}}\left(\left(\frac{x}{\sqrt{n}} + \theta \right)\right) =
# \begin{cases}
# 1, x \in [0, +\infty) \\
# (1 + \frac{x}{\sqrt{n}\theta})^n, x \in [-\theta \sqrt{n}, 0) \\
# 0, \text{ иначе }
# \end{cases}
# $$
# Предположим, оценка асимптотически нормальная. Тогда $F_{\sqrt{n}(X_{(n)} - \theta}(x) \to F_{N(0, 1)}(x)$ $\forall x$. Так как функция распределения стандартного нормального закона непрерывна на $\mathbb{R}$
# Но тогда $F(0) = 0$ - противоречие. Тогда и $\hat{\theta_1}$ - не асимптотически нормальная(иначе бы мы воспользовались теоремой о наследовании асимптотической нормальности и получили бы противоречие)
# $\hat{theta_2}$ же по ЦПТ является асимптотически нормальной оценкой $\theta$, причем асимптотическая дисперсия равна(по теореме о наследовании асимптотической нормальности) $2\mathbb{D} X_1 = \frac{\theta^2}{6}$
# $$\mathbb{E} X_{(n)}^2 = \int_{0}^{\theta} nx^2 \frac{x^{n - 1}}{\theta^n}dx = \theta^2 \frac{n}{n + 2} \rightarrow \mathbb{D} X_{(n)} = \theta^2n \left( \frac{1}{(n + 2)} - \frac{n}{(n + 1)^2}\right) = \theta^2 \frac{n}{(n + 1)^2(n + 2)} \rightarrow \mathbb{D} \frac{n + 1}{n}X_{(n)} = \frac{\theta^2}{(n + 1)(n + 2)}$$
#
# $$\mathbb{D}(2 \overline{X}) = \frac{4}{n} \mathbb{D} X_1 =  \frac{\theta^2}{3n}$$ Тогда

# %%
for theta, theta_1, theta_2 in uniform_statistics:
  print(f'Численная дисперсия theta_1: {np.var(np.array(theta_1))}, аналитическая дисперсия theta_1: {theta**2 / ((sel_size + 1) * (sel_size + 2))}')
  print(f'Численная дисперсия theta_2: {np.var(np.array(theta_2))}, аналитическая дисперсия theta_2: {theta**2 / (3 * sel_size)}')
# Out:
# Численная дисперсия theta_1: 0.0002641160366777177, аналитическая дисперсия theta_1: 0.00023109724538513264
# Численная дисперсия theta_2: 0.06966663956158778, аналитическая дисперсия theta_2: 0.07726366643859293
# Численная дисперсия theta_1: 8.847933569748083e-06, аналитическая дисперсия theta_1: 9.322786139144725e-06
# Численная дисперсия theta_2: 0.0035198493101683027, аналитическая дисперсия theta_2: 0.0031169243810448125
# Численная дисперсия theta_1: 0.00010785811130130217, аналитическая дисперсия theta_1: 0.00017143243646345921
# Численная дисперсия theta_2: 0.0418583668689017, аналитическая дисперсия theta_2: 0.057315692212574175

# %% [markdown]
# Сравнивая со скоростю сходимости в неравенстве Рао-Крамера, получаем, что скорость сходимост у оптимальной оценки выше, а у оценки по методу моментов такая же. Если бы были выполнены условия регулярности, то можно было бы применить неравенство Рао-Крамера и тогда любая оценка имела бы скорость сходимости $\Omega(\frac{1}{n}), n \to \infty$. То есть таких результатов не получилось бы

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Пусть $D = (Z^TZ)^{-1}, \hat{\theta} = DZ^TX, \hat{t} = A \hat{\theta}, B = ADA^T$. F - критерий выглядит следующим образом:
# $$\frac{(\hat{t} - \beta_0)^TB^{-1}(\hat{t} - \beta_0)}{||X - Z\hat{\theta}||^2} \frac{4n - 2}{1} > f_{1 - \alpha}(1, 4n - 2)$$

# %%
def get_lin_regression(n):
  sigma = 1
  theta_1 = 5
  theta_2 = 8
  theta = np.array([theta_1, theta_2])
  Z = np.zeros((4 * n, 2))
  for i in range(n):
    Z[i][0] = 1
    Z[i + n][1] = 1
    Z[2 * n + i][1] = 1
    Z[3 * n + i] = [1, 1]

  eps = norm.rvs(scale=1, size=4*n)
  X = Z @ theta + eps
  return X, Z

# %%
def check_F(X, Z, A, beta_0 = 0, alpha=0.05) -> bool:
  D = np.array(np.linalg.inv(Z.T @ Z))
  hat_theta = np.array(D @ Z.T @ X)
  hat_t = np.array(A @ hat_theta)
  B = A @ D @ A.T
  if B.size > 1:
    inv_B = np.linalg.inv(B)
  else:
    inv_B = np.array(1 / B)
  return np.array(hat_t.T.dot(inv_B)).dot(hat_t) * (Z.shape[0] - 2) > np.sum((X - Z @ hat_theta) ** 2) * f.ppf(q=1-alpha, dfn=1, dfd=Z.shape[0] - 2)

# %%
def check_hypothesis(A, beta_0 = 0, max_n = 200, alpha=0.05) -> list[int]:
  """
  for n in [1, max_n] model linear regression and check hypothesis A theta = beta_0 and return
  list of [xi_n], where xi_n = 1 if H_1 is true
  """
  res = [0] * max_n
  for n in range(1, max_n + 1):
    X, Z = get_lin_regression(n)
    res[n - 1] = int(check_F(X, Z, A, beta_0, alpha))
  return res

def plot_res(res: list[int], alpha=0.05):
  pref_sum = [res[0]] * len(res)
  for i in range(1, len(res)):
    pref_sum[i] = pref_sum[i - 1] + res[i]
  frac_true = [pref_sum[i] / (i + 1) for i in range(len(res))]
  plt.plot(range(len(res)), frac_true)
  plt.ylabel("Доля раз, когда отвергли H_0")
  if alpha < 1:
    plt.plot(range(len(res)), [alpha for _ in range(len(res))])
    plt.annotate(xy=(len(res) / 2, alpha), text="alpha", xytext=(2 * len(res) / 3, alpha + 0.15 * (max(frac_true) - min(frac_true))), arrowprops=dict(facecolor='black', shrink=0.001))

# %%
res_1 = check_hypothesis(np.array([8, -5]), max_n = 200)
plot_res(res_1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
res_2 = check_hypothesis(np.array([2, -3]), max_n = 200)
plot_res(res_2, 1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def compare_stats(n=200):
  X, Z = get_lin_regression(n)
  D = np.array(np.linalg.inv(Z.T @ Z))
  hat_theta = np.array(D @ Z.T @ X)
  print(f'Оптимальная оценка theta_1: {hat_theta[0]}, предложенная оценка: {np.sum(X[0:n]) / n}')
  print(f'Относительное отклонение оптимальной, {abs(hat_theta[0]/5 - 1)}, отн. отклонение предложенной {abs(np.sum(X[0:n]) / (n * 5) - 1)}')
  print(f'Оптимальная оценка theta_2: {hat_theta[1]}, альтернативная оценка: {np.sum(X[n:3 * n]) / (2 * n)}')
  print(f'Относительное отклонение оптимальной, {abs(hat_theta[1]/8 - 1)}, отн. отклонение предложенной {abs(np.sum(X[n:3 * n]) / (2 * n * 5) - 1)}')

compare_stats()
# Out:
# Оптимальная оценка theta_1: 4.984956966415707, предложенная оценка: 5.021039514390301
# Относительное отклонение оптимальной, 0.0030086067168586528, отн. отклонение предложенной 0.004207902878060166
# Оптимальная оценка theta_2: 7.967052046257857, альтернативная оценка: 7.9850933202451575
# Относительное отклонение оптимальной, 0.004118494217767887, отн. отклонение предложенной 0.5970186640490316

# %% [markdown]
# Действительно,
# $$\hat{\theta} = (Z^TZ)^{-1}Z^T X \rightarrow \hat{\theta} \sim \mathcal{N}(0, (Z^TZ)^{-1}Z^T \sigma^2 I_{4n} ((Z^TZ)^{-1}Z^T)^T)$$
# $$(Z^TZ)^{-1}Z^T \sigma^2 I_{4n} ((Z^TZ)^{-1}Z^T)^T = (Z^TZ)^{-1}Z^T \sigma^2 I_{4n} Z(Z^TZ)^{-1} = \sigma^2 (Z^TZ)^{-1}$$
# Для данной задачи $Z^TZ =
# \begin{pmatrix}
# 2n & n \\
# n & 3n \\
# \end{pmatrix} \rightarrow
# (Z^TZ)^{-1} =
# \frac{1}{5n}
# \begin{pmatrix}
# 3 & -1 \\
# -1 & 2
# \end{pmatrix}
# $
# Тогда $\mathbb{D} \hat{\theta_1} = \frac{3}{5n}\sigma^2, \mathbb{D} \hat{\theta_2} = \frac{2}{5n}\sigma^2$. Для предложенных оценок же
# $\mathbb{D} \sum_{i = 1}^n X_i = \frac{\sigma^2}{n}, \mathbb{D} \sum_{j = 1}^{2n} Y_j = \frac{\sigma^2}{2n}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Преобразуем следующим образом
#
# ![image.png](data:image/png;base64,...)

# %%
def calc_dn(selection):
  dn = 0
  selection = np.sort(selection)
  for k in range(len(selection)):
    dn = max(dn, max((k + 1) / len(selection) - norm.cdf(selection[k]),
                     norm.cdf(selection[k]) - k / len(selection)))
  return dn

def plot_dn(dns):
  plt.figure(figsize=(10, 7))
  plt.plot(range(len(dns)), dns)

# %%
selection = norm.rvs(size=sel_size)
dns = [calc_dn(selection[:n+1]) for n in range(len(selection))]
plot_dn(dns)

# %%
stats = [np.sqrt(i + 1) * dns[i] for i in range(len(dns))]
ecdf = ECDF(stats)
x = np.linspace(-1, 10, 100)
plt.figure(figsize=(8, 6))
plt.plot(x, ecdf(x), label='emperical')
plt.plot(x, kstwobign.cdf(x), label='kolmogorov')
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Точный доверительные интервал уровня значимости $\alpha$ равен $\left(\overline{X} + \frac{z_{\alpha/2}}{\sqrt{n}}, \overline{X} - \frac{z_{\alpha/2}}{\sqrt{n}} \right)$, где $z_p$ - кванитль уровня $p$ стандартного нормального закона(см. в задаче 18 второго задания).

# %%
def get_norm_interval(selection, alpha: float = 0.05) -> (float, float):
  z_alpha_half = norm.ppf(q=alpha/2)
  X_average = selection.mean()
  return X_average + z_alpha_half / np.sqrt(len(selection)), X_average - z_alpha_half / np.sqrt(len(selection))

def generate_norm_interval(theta: float, n: int, alpha: float=0.05) -> (float, float):
    return get_norm_interval(norm.rvs(loc=theta, size=n), alpha)

# %%
def plot_intervals(Theta: list[float], n: int, generate_interval=generate_norm_interval, alpha: float = 0.05):
  lefts = []
  rights = []
  plt.figure(figsize=(25, 13))
  for theta in Theta:
    left, right = generate_interval(theta, n, alpha)
    lefts.append(left)
    rights.append(right)
  plt.vlines(x=Theta, ymin=lefts, ymax=rights, color='r')
  plt.plot(Theta, Theta, ls='--', color='g', alpha=1)
  plt.grid()
  plt.show()

# %%
alpha = 0.05
Theta = [k / 10 for k in range(-100, 101)]
n = 200

# %%
plot_intervals(Theta, n, alpha=alpha)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ns = [5, 10, 100]

# %%
for n in ns:
  plot_intervals(Theta, n, alpha=alpha)

# %% [markdown]
# Длина доверительного интервала уменьшается, что легко заметить из формулы, причем его длина $\sim \frac{1}{\sqrt{n}}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Пользуясь неравенством Чебышева, получаем, что доверительный интервал равен(см 18 задачу 2 части дз)
# $$\left(\frac{2\overline{X} + \frac{1}{\alpha n} - \sqrt{\frac{4\overline{X}}{\alpha n} + \frac{1}{\alpha^2n^2}}}{2}, \frac{2\overline{X} + \frac{1}{\alpha n} + \sqrt{\frac{4\overline{X}}{\alpha n} + \frac{1}{n^2\alpha^2}}}{2}\right)$$
# Также можем указать асимптотический доверительный интервал для $\theta$:
# $$\left(\overline{X} + z_{\alpha/2}\sqrt{\frac{\overline{X}}{n}}, \overline{X} - z_{\alpha/2}\sqrt{\frac{\overline{X}}{n}}\right)$$,
# где $z_p$ - квантиль уровня $p$ стандартного нормального закона.

# %%
def get_poisson_interval(selection, alpha: float = 0.05) -> (float, float):
    mean = np.mean(selection)
    n = len(selection)
    discriminant_sq = np.sqrt(4 * mean / (alpha * n) + 1 / ((alpha * n)**2))
    minus_b = 2 * mean + 1 / (alpha * n)
    return (minus_b - discriminant_sq) / 2, (minus_b + discriminant_sq) / 2

def get_asymptotic_poisson_interval(selection, alpha: float = 0.05) -> (float, float):
    z_alpha_half = norm.ppf(q=alpha/2)
    mean = selection.mean()
    n = len(selection)
    return mean + z_alpha_half * np.sqrt(mean / n), mean - z_alpha_half * np.sqrt(mean / n)

def generate_poisson_interval(theta: float, n: int, alpha: float = 0.05) -> (float, float):
    return get_poisson_interval(poisson.rvs(theta, size=n), alpha)

def generate_asymptotic_poisson_interval(theta: float, n: int, alpha: float = 0.05) -> (float, float):
    return get_asymptotic_poisson_interval(poisson.rvs(theta, size=n), alpha)

# %%
Theta = [k / 10 for k in range(1, 101)]

# %%
plot_intervals(Theta, n, generate_poisson_interval, alpha)

# %%
for n in ns:
  plot_intervals(Theta, n, generate_poisson_interval, alpha)

# %% [markdown]
# Теперь попробуем асимптотические интервалы

# %%
plot_intervals(Theta, n, generate_asymptotic_poisson_interval, alpha)

# %%
for n in ns:
  plot_intervals(Theta, n, generate_asymptotic_poisson_interval, alpha)

# %% [markdown]
# ![image.png](attachment:adcb80ce-9678-40d0-ac29-a359d3b74788.png)

# %% [markdown]
# Найдем бинарным поиском. Пусть $z_p$ - искомый квантиль. Предположим, $p > \frac{1}{2}$. Тогда за левую границу возьмем $\mathbb{E} X_1$, а правую посчитаем с помощью неравенства Чебышева
# $$P(|X_1 - \mathbb{E} X_1| > \varepsilon) \le \frac{\mathbb{D} X_1}{\varepsilon^2} \le 1 - p \rightarrow \varepsilon = \sqrt{\frac{\mathbb{D} X_1}{1 - p}}$$
# Отсюда за правую границу можно взять $\mathbb{E} X_1 + \varepsilon$
# Аналогично, если $p < \frac{1}{2}$, то квантиль точно лежит в $\left(\mathbb{E} X_1 - \sqrt{\frac{\mathbb{D} X_1}{p}}, \mathbb{E} X_1\right)$

# %%
mean = 70
var = 10

# %% [markdown]
# ![image.png](attachment:cadf1516-7bd5-44e7-9a84-d2650579a866.png)

# %%
def estimate_std(selection, statistic, bootstrap_count=1000):
    bootstrap_stats = []
    for _ in range(bootstrap_count):
        new_selection = np.random.choice(selection, len(selection), replace=True)
        bootstrap_stats.append(statistic(new_selection))
    return np.std(bootstrap_stats)

def research(p: float):
    selection = norm.rvs(loc=mean, scale=var, size=sel_size)
    quantile = np.quantile(selection, p)
    real_quantile = round(norm.ppf(q=p, loc=mean, scale=var), 2)
    std = estimate_std(selection, lambda selection: np.quantile(selection, p))
    print(f'Реальный квантиль: {real_quantile}')
    print(f'Посчитанный квантиль: {quantile}')
    print(f'Посчитанная с помощью бутстрепа погрешность: {std}')
    print(f'Реальная погрешность: {abs(quantile - real_quantile)}')

# %%
research(0.95)
# Out:
# Реальный квантиль: 86.45
# Посчитанный квантиль: 87.12730465921899
# Посчитанная с помощью бутстрепа погрешность: 0.9315170125092896
# Реальная погрешность: 0.67730465921899

# %%
research(0.9)
# Out:
# Реальный квантиль: 82.82
# Посчитанный квантиль: 81.87876183882875
# Посчитанная с помощью бутстрепа погрешность: 0.5674887380025924
# Реальная погрешность: 0.9412381611712419

# %%
research(0.8)
# Out:
# Реальный квантиль: 78.42
# Посчитанный квантиль: 78.38786816973821
# Посчитанная с помощью бутстрепа погрешность: 0.4613608225630604
# Реальная погрешность: 0.03213183026178967
